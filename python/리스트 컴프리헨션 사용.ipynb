# %% [markdown]
# 리스트 컴프리헨션 사용

# %%
even = []
for x in range(10):
  if x % 2 == 0:
    even.append(x)
    print(even)
# Out:
# [0]
# [0, 2]
# [0, 2, 4]
# [0, 2, 4, 6]
# [0, 2, 4, 6, 8]

# %%
even2 = [ x for x in range(10) if x % 2 == 0]
even2
# Out:
# [0, 2, 4, 6, 8]

# %%
squares = [ x**2 for x in range(10) ]
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
