# %% [markdown]
# # 파일(file)
# ### **파일 생성**
# * 파일 객체 = open(파일이름, 파일 열기 모드, encoding='UTF-8' )
#  - 파일명이 한글일 경우는 encoing='UTF-8'을 사용
#
# ### **파일출력함수 : write()**
# ### **파일입력함수**
# * readline(): 파일 첫 번째 줄을 읽어 출력하는 경우
# * readlines(): 파일의 모든 라인을 읽어서 각각의 줄을 요소로 갖는 리스트로 리턴
# * read(): 파일의 내용 전체를 문자열로 리턴
#
# ### **파일 닫기**
# * 파일 객체.close()

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
fp = open('/content/지역평균기온 (1).txt', 'r', encoding='utf-8')
fp
# Out:
# <_io.TextIOWrapper name='/content/지역평균기온 (1).txt' mode='r' encoding='utf-8'>

# %%
data = fp.read
data
# Out:
# <function TextIOWrapper.read(size=-1, /)>

# %%
data2 = fp.readlines()
data2
# Out:
# ['서울,20\n',
#  '부산,26\n',
#  '대구,24\n',
#  '인천,24\n',
#  '광주,25\n',
#  '대전,22\n',
#  '울산,26\n',
#  '세종,23\n',
#  '경기,24\n',
#  '강원,23\n',
#  '충북,26\n',
#  '충남,22\n',
#  '전북,24\n',
#  '전남,23\n',
#  '경북,28\n',
#  '경남,29\n',
#  '제주,26\n']

# %%
fp.close()

# %%
fp = open('/content/지역평균기온 (1).txt', 'r', encoding='utf-8')
data = fp.readlines()
fp.close()

# %%
dt = {}
for line in data :
  line = line.replace('\n', '')
  items = line.split(',')
  dt[items[0]] = int(items[1])

print(type(dt))
print(dt)
dt
# Out:
# <class 'dict'>
# {'서울': 20, '부산': 26, '대구': 24, '인천': 24, '광주': 25, '대전': 22, '울산': 26, '세종': 23, '경기': 24, '강원': 23, '충북': 26, '충남': 22, '전북': 24, '전남': 23, '경북': 28, '경남': 29, '제주': 26}
# {'서울': 20,
#  '부산': 26,
#  '대구': 24,
#  '인천': 24,
#  '광주': 25,
#  '대전': 22,
#  '울산': 26,
#  '세종': 23,
#  '경기': 24,
#  '강원': 23,
#  '충북': 26,
#  '충남': 22,
#  '전북': 24,
#  '전남': 23,
#  '경북': 28,
#  '경남': 29,
#  '제주': 26}

# %%
with open('/content/지역평균기온 (1).txt', 'r', encoding='utf-8') as fp :
  data = fp.readlines()
print(data)
# Out:
# ['서울,20\n', '부산,26\n', '대구,24\n', '인천,24\n', '광주,25\n', '대전,22\n', '울산,26\n', '세종,23\n', '경기,24\n', '강원,23\n', '충북,26\n', '충남,22\n', '전북,24\n', '전남,23\n', '경북,28\n', '경남,29\n', '제주,26\n']
